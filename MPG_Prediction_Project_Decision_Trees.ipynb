# %% [markdown]
# <a href="https://colab.research.google.com/github/ItzNotCheetah/MPG-Prediction-Project-Decision-Trees/blob/main/MPG_Prediction_Project_Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPG Prediction Using Decision Tree Regression

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv('auto-mpg.csv')
features = ['cylinders', 'horsepower', 'weight', 'acceleration', 'model year', 'origin']
X = dataset[features]
y = dataset['mpg']

# %%
print(X)
# Out:
#      cylinders horsepower  weight  acceleration  model year  origin
# 0            8        130    3504          12.0          70       1
# 1            8        165    3693          11.5          70       1
# 2            8        150    3436          11.0          70       1
# 3            8        150    3433          12.0          70       1
# 4            8        140    3449          10.5          70       1
# ..         ...        ...     ...           ...         ...     ...
# 393          4         86    2790          15.6          82       1
# 394          4         52    2130          24.6          82       2
# 395          4         84    2295          11.6          82       1
# 396          4         79    2625          18.6          82       1
# 397          4         82    2720          19.4          82       1
#
# [398 rows x 6 columns]

# %%
print(y)
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
X = X.replace('?', np.nan)
X = X.apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 0)

# %% [markdown]
# # Training the Decision Tree Regression model on the Training set

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state= 0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# # Visualising the Decision Tree Regression results (Actual vs Predicted)

# %%
y_pred = regressor.predict(X_test)
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Decision Tree Predictions vs Actual')
plt.show()
